# %% [markdown]
# ---
#
# ## ¿Cómo varía el potencial solar estimado a lo largo del día y del mes en Riohacha y en la Patagonia?
#
# #### DIARIO:
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
#
# #### MENSUAL:
# ![image-4.png](attachment:image-4.png)
# ![image-3.png](attachment:image-3.png)
#
# ### RTA: Se observa que la Patagonia presenta mayor variacion de potencial solar diario y mensual

# %% [markdown]
# ---
#
# ## ¿Qué patrones históricos se observan en el potencial eólico de ambas ubicaciones?
#
# #### DIARIO:
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# #### MENSUAL:
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# ### RTA: Se observa que la Patagonia presenta historicamente mayor variacion y magnitud de potencial eolico.

# %% [markdown]
# ---
#
# ## ¿Cuáles fueron los días con mayor y menor potencial energético en cada ubicación durante el periodo de análisis?
#
# ### RTA:
# #### MAX ENERGY PATAGONIA:
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# #### MAX ENERGY RIOHACHA:
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# #### MIN ENERGY PATAGONIA:
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
#
# #### MIN ENERGY RIOHACHA:
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
